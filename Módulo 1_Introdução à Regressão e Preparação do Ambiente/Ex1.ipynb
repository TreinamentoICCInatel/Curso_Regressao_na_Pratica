# %% [markdown]
# ### Atividade de fixação

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Importando dataset
df = pd.read_csv("notas.csv")

# %%
# Exibindo primeiras linhas
print(df.head())
# Out:
#    horas_estudo  pontuacao
# 0             1         35
# 1             2         40
# 2             3         52
# 3             4         47
# 4             5         60

# %%
# Plotando gráfico de dispersão
plt.scatter(df["horas_estudo"], df["pontuacao"], color="orange")
plt.title("Relação entre horas de estudo e pontuação em teste")
plt.xlabel("Horas de Estudo")
plt.ylabel("Pontuação")
plt.grid(True, linestyle="--", alpha=0.6)
plt.show()

# %% [markdown]
# ## 🧩 Exercício – Revisando o que aprendemos
#
# ### ⚙️ Instruções
# 1. Execute todas as células de código acima em ordem.
# 2. Observe atentamente o gráfico de dispersão e a saída do `print(df.head())`.
# 3. Use essas informações para responder às perguntas no espaço indicado no material do curso.
#
# ---
#
# ### 🧠 Perguntas
#
# 1. Qual biblioteca usamos para carregar e manipular o dataset?
#    a) NumPy
#    b) Pandas
#    c) Seaborn
#    d) Scikit-learn
#
# 2. Qual biblioteca usamos para criar o gráfico de dispersão?
#    a) TensorFlow
#    b) Matplotlib
#    c) Pandas
#    d) Plotly
#
# 3. Qual variável é dependente e qual é independente?
#    a) Dependente: horas de estudo | Independente: pontuação
#    b) Dependente: pontuação | Independente: horas de estudo
#    c) Ambas são dependentes
#    d) Nenhuma das anteriores
#
# 4. O que você esperaria acontecer se um aluno estudasse 12 horas?
#    a) A pontuação diminuiria
#    b) A pontuação aumentaria, seguindo a tendência observada
#    c) A pontuação se manteria igual
#    d) Não é possível prever com base no gráfico
